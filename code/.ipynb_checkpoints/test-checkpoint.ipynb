# %%
import pandas as pd

# %%
s = """
台大椰林步道
台北市大安區
難度低、1.68公里、20 分鐘、必須折返
flag
去過此路線
路線資訊
大安森林公園
台北市大安區
難度低、2.2公里、45 分鐘、環狀
flag
去過此路線
路線資訊
大湖公園(防災公園)
台北市內湖區
難度低、1.15公里、20 分鐘、雙向進出
flag
去過此路線
路線資訊
虎山親山步道
台北市信義區
難度低、2.5公里、2 小時 30 分鐘、雙向進出
flag
去過此路線
路線資訊
天母水管路步道(天母古道)
台北市北投區
難度低、2.6公里、1 小時 30 分鐘、雙向進出
flag
去過此路線
路線資訊
仙跡岩步道
台北市文山區
難度低、3.54公里、1 小時 20 分鐘、雙向進出
flag
去過此路線
路線資訊
擎天崗環形步道
台北市北投區
難度低、2.4公里、1 小時 、環狀
flag
去過此路線
路線資訊
文山農場
新北市新店區
難度低、0.86公里、22 分鐘、環狀
flag
去過此路線
路線資訊
烘爐地登山步道(南勢角山)
新北市中和區
難度低、4公里、2 小時 、必須折返
flag
去過此路線
路線資訊
鼻頭角步道
新北市瑞芳區
難度低、3.5公里、1 小時 30 分鐘、環狀
flag
去過此路線
路線資訊
忘憂谷步道
基隆市
難度低、1.7公里、1 小時 、雙向進出
flag
去過此路線
路線資訊
金面山親山步道
台北市內湖區
難度低-中、3公里、1 小時 、雙向進出
flag
去過此路線
路線資訊
鳶山彩壁、福德坑山步道
新北市三峽區
難度低、4公里、2 小時 、必須折返
flag
去過此路線
路線資訊
草嶺古道(官方指南)
新北市貢寮區,宜蘭縣頭城鎮
難度低、5.94公里、3 小時 、雙向進出
flag
去過此路線
路線資訊
羊稠森林步道
桃園市蘆竹區
難度低、6.4公里、2 小時 、必須折返
flag
去過此路線
路線資訊
桃園虎頭山步道
桃園市桃園區,桃園市龜山區
難度低、6.4公里、1 小時 50 分鐘、環狀
flag
去過此路線
路線資訊
石門水庫楓林步道
桃園市大溪區
難度低、1公里、25 分鐘、環狀
flag
去過此路線
路線資訊
齋明寺古道
桃園市大溪區
難度低、1公里、30 分鐘、雙向進出
flag
去過此路線
路線資訊
鳳崎落日步道
新竹縣新豐鄉,新竹縣竹北市
難度低、3公里、1 小時 40 分鐘、雙向進出
flag
去過此路線
路線資訊
飛鳳山、觀日坪古道
新竹縣芎林鄉
難度低、6公里、2 小時 40 分鐘、環狀
flag
去過此路線
路線資訊
馬胎古道
新竹縣尖石鄉
難度低-中、4.6公里、2 小時 15 分鐘、必須折返
flag
去過此路線
路線資訊
竹南海濱森林步道
苗栗縣竹南鎮
難度低、5公里、1 小時 20 分鐘、雙向進出
flag
去過此路線
路線資訊
貓貍山公園、功維敘隧道
苗栗縣苗栗市
難度低、2.6公里、50 分鐘、環狀
flag
去過此路線
路線資訊
通霄虎頭山步道
苗栗縣通霄鎮
難度低、0.6公里、30 分鐘、必須折返
flag
去過此路線
路線資訊
南庄向天湖山步道
苗栗縣南庄鄉
難度低-中、5公里、2 小時 45 分鐘、必須折返
flag
去過此路線
路線資訊
出關古道：聖關段(關刀山步道)
苗栗縣大湖鄉,苗栗縣三義鄉
難度低、3.5公里、1 小時 30 分鐘、雙向進出
flag
去過此路線
路線資訊
火炎山、南鞍古道O走
苗栗縣三義鄉
難度低-中、6.4公里、3 小時 、環狀
flag
去過此路線
路線資訊
柳川水岸景觀步道
台中市中區
難度低、0.8公里、20 分鐘、環狀
flag
去過此路線
路線資訊
台中都會公園步道
台中市西屯區,台中市沙鹿區
難度低、4.9公里、1 小時 30 分鐘、環狀
flag
去過此路線
路線資訊
高美濕地木棧道
台中市清水區
難度低、1.2公里、20 分鐘、必須折返
flag
去過此路線
路線資訊
大坑9、10號步道
台中市北屯區
難度低、2.7公里、1 小時 5 分鐘、環狀
flag
去過此路線
路線資訊
東海大學
台中市西屯區
難度低、2.23公里、50 分鐘、環狀
flag
去過此路線
路線資訊
八卦山天空步道
彰化縣彰化市
難度低、1.2公里、25 分鐘、雙向進出
flag
去過此路線
路線資訊
貓囒山步道
南投縣魚池鄉
難度低、2.7公里、2 小時 、必須折返
flag
去過此路線
路線資訊
雲林古坑綠色隧道
雲林縣古坑鄉
難度低、1.23公里、18 分鐘、環狀
flag
去過此路線
路線資訊
中正大學
嘉義縣民雄鄉
難度低、3.01公里、1 小時 13 分鐘、環狀
flag
去過此路線
路線資訊
國立故宮博物院南部院區- 嘉義
嘉義縣太保市
難度低、1.22公里、18 分鐘、環狀
flag
去過此路線
路線資訊
台中中央公園
台中市西屯區
難度低、2.69公里、1 小時 、雙向進出
flag
去過此路線
路線資訊
稍來山步道
台中市和平區
難度低-中、3.8公里、3 小時 、雙向進出
flag
去過此路線
路線資訊
合歡東峰步道
南投縣仁愛鄉,花蓮縣秀林鄉
難度低-中、2.2公里、2 小時 30 分鐘、必須折返
flag
去過此路線
路線資訊
漁光島步道
台南市安平區
難度低、2.3公里、35 分鐘、環狀
flag
去過此路線
路線資訊
虎形山公園步道
台南市龍崎區
難度低、1.6公里、40 分鐘、環狀
flag
去過此路線
路線資訊
台南市巴克禮公園
台南市東區
難度低、1.49公里、18 分鐘、環狀
flag
去過此路線
路線資訊
大東濕地公園步道
高雄市鳳山區
難度低、1公里、20 分鐘、環狀
flag
去過此路線
路線資訊
半屏山步道
高雄市楠梓區,高雄市左營區
難度低、3.2公里、2 小時 、雙向進出
flag
去過此路線
路線資訊
田寮月世界地景步道
高雄市田寮區
難度低、2.2公里、1 小時 、環狀
flag
去過此路線
路線資訊
大崗山步道
高雄市阿蓮區
難度低、4公里、2 小時 30 分鐘、環狀
flag
去過此路線
路線資訊
漯底山自然公園步道
高雄市彌陀區
難度低、2公里、1 小時 、環狀
flag
去過此路線
路線資訊
阿公店水庫環湖步道
高雄市岡山區
難度低、7公里、1 小時 30 分鐘、環狀
flag
去過此路線
路線資訊
高雄都會公園
高雄市楠梓區
難度低、1.89公里、28 分鐘、環狀
flag
去過此路線
路線資訊
旗后(後)山景觀步道
高雄市旗津區
難度低、0.54公里、20 分鐘、環狀
flag
去過此路線
路線資訊
蓮池潭環潭步道
高雄市左營區
難度低、3.47公里、1 小時 23 分鐘、環狀
flag
去過此路線
路線資訊
壽山、泰國谷、一簾幽夢步道
高雄市鼓山區
難度低-中、7.7公里、3 小時 、雙向進出
flag
去過此路線
路線資訊
五峰旗瀑布步道
宜蘭縣礁溪鄉
難度低、1公里、40 分鐘、必須折返
flag
去過此路線
路線資訊
林美石磐步道
宜蘭縣礁溪鄉
難度低、1.7公里、1 小時 、環狀
flag
去過此路線
路線資訊
見晴懷古步道
宜蘭縣大同鄉
難度低、1.8公里、50 分鐘、必須折返
flag
去過此路線
路線資訊
翠峰湖環山步道
宜蘭縣大同鄉
難度低、4.95公里、2 小時 50 分鐘、環狀
flag
去過此路線
路線資訊
羅東運動公園步道
宜蘭縣羅東鎮
難度低、3.5公里、1 小時 10 分鐘、環狀
flag
去過此路線
路線資訊
太麻里金針山步道
台東縣太麻里鄉
難度低、7公里、2 小時 30 分鐘、環狀
flag
去過此路線
路線資訊
聖母登山步道（抹茶山）
宜蘭縣礁溪鄉
難度低-中、10.66公里、5 小時 、必須折返
flag
"""

# %%
lst_all = []
for i in s.split('路線資訊'):
    dic = {}
    lst = i.strip().split("\n")
    dic['name'] = lst[0]
    dic['location'] = lst[1]
    dic['km'] = lst[2].split('、')[1]
    dic['time'] = lst[2].split('、')[2]
    dic['circle'] = lst[2].split('、')[3]
    lst_all.append(dic)
    break

# %%
a = pd.DataFrame(lst_all)
# a.to_excel('hiking.xlsx', index=False)
a['time'] = a['time'].apply(lambda x : x if '小時' in x else '0 小時 '+x)
a
# Out:
#                name       location       km        time circle
# 0            台大椰林步道         台北市大安區   1.68公里  0 小時 20 分鐘   必須折返
# 1            大安森林公園         台北市大安區    2.2公里  0 小時 45 分鐘     環狀
# 2        大湖公園(防災公園)         台北市內湖區   1.15公里  0 小時 20 分鐘   雙向進出
# 3            虎山親山步道         台北市信義區    2.5公里  2 小時 30 分鐘   雙向進出
# 4     天母水管路步道(天母古道)         台北市北投區    2.6公里  1 小時 30 分鐘   雙向進出
# 5             仙跡岩步道         台北市文山區   3.54公里  1 小時 20 分鐘   雙向進出
# 6           擎天崗環形步道         台北市北投區    2.4公里       1 小時      環狀
# 7              文山農場         新北市新店區   0.86公里  0 小時 22 分鐘     環狀
# 8     烘爐地登山步道(南勢角山)         新北市中和區      4公里       2 小時    必須折返
# 9             鼻頭角步道         新北市瑞芳區    3.5公里  1 小時 30 分鐘     環狀
# 10            忘憂谷步道            基隆市    1.7公里       1 小時    雙向進出
# 11          金面山親山步道         台北市內湖區      3公里       1 小時    雙向進出
# 12      鳶山彩壁、福德坑山步道         新北市三峽區      4公里       2 小時    必須折返
# 13       草嶺古道(官方指南)  新北市貢寮區,宜蘭縣頭城鎮   5.94公里       3 小時    雙向進出
# ...
